# %%
from os.path import join

import cv2
import torch
from matplotlib import pyplot as plt

from gluestick import batch_to_np, numpy_image_to_torch, GLUESTICK_ROOT
from gluestick.drawing import plot_images, plot_lines, plot_color_line_matches, plot_keypoints, plot_matches
from gluestick.models.two_view_pipeline import TwoViewPipeline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 7
#       4 import torch
#       5 from matplotlib import pyplot as plt
# ----> 7 from gluestick import batch_to_np, numpy_image_to_torch, GLUESTICK_ROOT
#       8 from gluestick.drawing import plot_images, plot_lines, plot_color_line_matches, plot_keypoints, plot_matches
#       9 from gluestick.models.two_view_pipeline import TwoViewPipeline
#
# File ~/GlueStick/gluestick/models/gluestick.py:8
#       6 import torch.utils.checkpoint
#       7 from torch import nn
# ----> 8 from .base_model import BaseModel
#      10 ETH_EPS = 1e-8
#      13 class GlueStick(BaseModel):
#
# ImportError: attempted relative import with no known parent package

# %%
import numpy as np
import torch

from .. import get_model
from .base_model import BaseModel

from collections import namedtuple
def keep_quadrant_kp_subset(keypoints, scores, descs, h, w):
    """Keep only keypoints in one of the four quadrant of the image."""
    h2, w2 = h // 2, w // 2
    w_x = np.random.choice([0, w2])
    w_y = np.random.choice([0, h2])
    valid_mask = ((keypoints[..., 0] >= w_x)
                  & (keypoints[..., 0] < w_x + w2)
                  & (keypoints[..., 1] >= w_y)
                  & (keypoints[..., 1] < w_y + h2))
    keypoints = keypoints[valid_mask][None]
    scores = scores[valid_mask][None]
    descs = descs.permute(0, 2, 1)[valid_mask].t()[None]
    return keypoints, scores, descs


def keep_random_kp_subset(keypoints, scores, descs, num_selected):
    """Keep a random subset of keypoints."""
    num_kp = keypoints.shape[1]
    selected_kp = torch.randperm(num_kp)[:num_selected]
    keypoints = keypoints[:, selected_kp]
    scores = scores[:, selected_kp]
    descs = descs[:, :, selected_kp]
    return keypoints, scores, descs


def keep_best_kp_subset(keypoints, scores, descs, num_selected):
    """Keep the top num_selected best keypoints."""
    sorted_indices = torch.sort(scores, dim=1)[1]
    selected_kp = sorted_indices[:, -num_selected:]
    keypoints = torch.gather(keypoints, 1,
                             selected_kp[:, :, None].repeat(1, 1, 2))
    scores = torch.gather(scores, 1, selected_kp)
    descs = torch.gather(descs, 2,
                         selected_kp[:, None].repeat(1, descs.shape[1], 1))
    return keypoints, scores, descs


class TwoViewPipeline(BaseModel):
    default_conf = {
        'extractor': {
            'name': 'superpoint',
            'trainable': False,
        },
        'use_lines': False,
        'use_points': True,
        'randomize_num_kp': False,
        'detector': {'name': None},
        'descriptor': {'name': None},
        'matcher': {'name': 'nearest_neighbor_matcher'},
        'filter': {'name': None},
        'solver': {'name': None},
        'ground_truth': {
            'from_pose_depth': False,
            'from_homography': False,
            'th_positive': 3,
            'th_negative': 5,
            'reward_positive': 1,
            'reward_negative': -0.25,
            'is_likelihood_soft': True,
            'p_random_occluders': 0,
            'n_line_sampled_pts': 50,
            'line_perp_dist_th': 5,
            'overlap_th': 0.2,
            'min_visibility_th': 0.5
        },
    }
    required_data_keys = ['image0', 'image1']
    strict_conf = False  # need to pass new confs to children models
    components = [
        'extractor', 'detector', 'descriptor', 'matcher', 'filter', 'solver']

    def _init(self, conf):
        if conf.extractor.name:
            self.extractor = get_model(conf.extractor.name)(conf.extractor)
        else:
            if self.conf.detector.name:
                self.detector = get_model(conf.detector.name)(conf.detector)
            else:
                self.required_data_keys += ['keypoints0', 'keypoints1']
            if self.conf.descriptor.name:
                self.descriptor = get_model(conf.descriptor.name)(
                    conf.descriptor)
            else:
                self.required_data_keys += ['descriptors0', 'descriptors1']

        if conf.matcher.name:
            self.matcher = get_model(conf.matcher.name)(conf.matcher)
        else:
            self.required_data_keys += ['matches0']

        if conf.filter.name:
            self.filter = get_model(conf.filter.name)(conf.filter)

        if conf.solver.name:
            self.solver = get_model(conf.solver.name)(conf.solver)

    def _forward(self, data):

        def process_siamese(data, i):
            data_i = {k[:-1]: v for k, v in data.items() if k[-1] == i}
            if self.conf.extractor.name:
                pred_i = self.extractor(data_i)
            else:
                pred_i = {}
                if self.conf.detector.name:
                    pred_i = self.detector(data_i)
                else:
                    for k in ['keypoints', 'keypoint_scores', 'descriptors',
                              'lines', 'line_scores', 'line_descriptors',
                              'valid_lines']:
                        if k in data_i:
                            pred_i[k] = data_i[k]
                if self.conf.descriptor.name:
                    pred_i = {
                        **pred_i, **self.descriptor({**data_i, **pred_i})}
            return pred_i

        pred0 = process_siamese(data, '0')
        pred1 = process_siamese(data, '1')

        pred = {**{k + '0': v for k, v in pred0.items()},
                **{k + '1': v for k, v in pred1.items()}}

        if self.conf.matcher.name:
            pred = {**pred, **self.matcher({**data, **pred})}

        if self.conf.filter.name:
            pred = {**pred, **self.filter({**data, **pred})}

        if self.conf.solver.name:
            pred = {**pred, **self.solver({**data, **pred})}
        MyTuple = namedtuple('MyTuple', pred)
        my_tuple = MyTuple(**d)
        return my_tuple

    def loss(self, pred, data):
        losses = {}
        total = 0
        for k in self.components:
            if self.conf[k].name:
                try:
                    losses_ = getattr(self, k).loss(pred, {**pred, **data})
                except NotImplementedError:
                    continue
                losses = {**losses, **losses_}
                total = losses_['total'] + total
        return {**losses, 'total': total}

    def metrics(self, pred, data):
        metrics = {}
        for k in self.components:
            if self.conf[k].name:
                try:
                    metrics_ = getattr(self, k).metrics(pred, {**pred, **data})
                except NotImplementedError:
                    continue
                metrics = {**metrics, **metrics_}
        return metrics
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 16
#      13 import numpy as np
#      14 import torch
# ---> 16 from .. import get_model
#      17 from .base_model import BaseModel
#      19 from collections import namedtuple
#
# ImportError: attempted relative import with no known parent package

# %%
MAX_N_POINTS, MAX_N_LINES = 1000, 300

# Evaluation config
conf = {
    'name': 'two_view_pipeline',
    'use_lines': True,
    'extractor': {
        'name': 'wireframe',
        'sp_params': {
            'force_num_keypoints': False,
            'max_num_keypoints': MAX_N_POINTS,
        },
        'wireframe_params': {
            'merge_points': True,
            'merge_line_endpoints': True,
        },
        'max_n_lines': MAX_N_LINES,
    },
    'matcher': {
        'name': 'gluestick',
        'weights': str(GLUESTICK_ROOT / 'resources' / 'weights' / 'checkpoint_GlueStick_MD.tar'),
        'trainable': False,
    },
    'ground_truth': {
        'from_pose_depth': False,
    }
}

device = 'cpu'

model = TwoViewPipeline(conf).to(device).eval()

# %%
gray0 = cv2.imread("/home/jaeho/color_300.png", 0)
gray1 = cv2.imread("/home/jaeho/color_373.png", 0)

torch_gray0, torch_gray1 = numpy_image_to_torch(gray0), numpy_image_to_torch(gray1)
torch_gray0, torch_gray1 = torch_gray0.to(device)[None], torch_gray1.to(device)[None]
x = {'image0': torch_gray0, 'image1': torch_gray1}
# pred = model(x)Q
# torch.save(model.state_dict(), 'model.pt')
script_model = torch.jit.trace(model,x)
script_model.save("GlueStick.pt")
# Out:
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:146: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert b_size == 1, "Only batch size of 1 accepted for non padded inputs"
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:112: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
#   for b in range(len(x)):
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:114: TracerWarning: Converting a tensor to a NumPy array might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   img = (x[b].squeeze().cpu().numpy() * 255).astype(np.uint8)
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:132: TracerWarning: torch.from_numpy results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   lines.append(torch.from_numpy(b_segs[indices, :4].reshape(-1, 2, 2)))
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:133: TracerWarning: torch.from_numpy results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   scores.append(torch.from_numpy(b_scores[indices]))
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:170: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if line_scores.shape[-1] != 0:
# /home/jaeho/GlueStick/gluestick/models/superpoint.py:113: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if image.shape[1] == 3:  # RGB
# /home/jaeho/GlueStick/gluestick/models/superpoint.py:163: TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
#   keypoints = [
# /home/jaeho/GlueStick/gluestick/models/superpoint.py:166: TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
#   scores = [s[tuple(k.t())] for s, k in zip(scores, keypoints)]
# /home/jaeho/GlueStick/gluestick/models/superpoint.py:166: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
#   scores = [s[tuple(k.t())] for s, k in zip(scores, keypoints)]
# /home/jaeho/GlueStick/gluestick/models/superpoint.py:48: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
#   if k >= len(keypoints):
# /home/jaeho/GlueStick/gluestick/models/superpoint.py:198: TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
#   for k, d in zip(keypoints, all_desc)]
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:186: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
#   assert len(kp) == 1
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:193: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
#   if self.conf.wireframe_params.merge_line_endpoints and len(lines[0]) > 0:
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:34: TracerWarning: Converting a tensor to a NumPy array might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   endpoints[bs].cpu().numpy())
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:40: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   clusters = torch.tensor(clusters, dtype=torch.long,
# /home/jaeho/GlueStick/gluestick/models/superpoint.py:57: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   keypoints /= torch.tensor([(w * s - s / 2 - 0.5), (h * s - s / 2 - 0.5)],
# /home/jaeho/GlueStick/gluestick/models/superpoint.py:57: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   keypoints /= torch.tensor([(w * s - s / 2 - 0.5), (h * s - s / 2 - 0.5)],
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:211: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
#   associativity = torch.eye(len(all_points[-1]), dtype=torch.bool, device=device)
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:248: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   'num_junctions': torch.tensor(num_true_junctions),
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:146: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert b_size == 1, "Only batch size of 1 accepted for non padded inputs"
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:112: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
#   for b in range(len(x)):
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:114: TracerWarning: Converting a tensor to a NumPy array might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   img = (x[b].squeeze().cpu().numpy() * 255).astype(np.uint8)
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:132: TracerWarning: torch.from_numpy results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   lines.append(torch.from_numpy(b_segs[indices, :4].reshape(-1, 2, 2)))
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:133: TracerWarning: torch.from_numpy results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   scores.append(torch.from_numpy(b_scores[indices]))
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:170: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if line_scores.shape[-1] != 0:
# /home/jaeho/GlueStick/gluestick/models/superpoint.py:113: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if image.shape[1] == 3:  # RGB
# /home/jaeho/GlueStick/gluestick/models/superpoint.py:163: TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
#   keypoints = [
# /home/jaeho/GlueStick/gluestick/models/superpoint.py:166: TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
#   scores = [s[tuple(k.t())] for s, k in zip(scores, keypoints)]
# /home/jaeho/GlueStick/gluestick/models/superpoint.py:166: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
#   scores = [s[tuple(k.t())] for s, k in zip(scores, keypoints)]
# /home/jaeho/GlueStick/gluestick/models/superpoint.py:48: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
#   if k >= len(keypoints):
# /home/jaeho/GlueStick/gluestick/models/superpoint.py:198: TracerWarning: Iterating over a tensor might cause the trace to be incorrect. Passing a tensor of different shape won't change the number of iterations executed (and might lead to errors or silently give incorrect results).
#   for k, d in zip(keypoints, all_desc)]
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:186: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
#   assert len(kp) == 1
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:193: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
#   if self.conf.wireframe_params.merge_line_endpoints and len(lines[0]) > 0:
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:34: TracerWarning: Converting a tensor to a NumPy array might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   endpoints[bs].cpu().numpy())
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:40: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   clusters = torch.tensor(clusters, dtype=torch.long,
# /home/jaeho/GlueStick/gluestick/models/superpoint.py:57: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   keypoints /= torch.tensor([(w * s - s / 2 - 0.5), (h * s - s / 2 - 0.5)],
# /home/jaeho/GlueStick/gluestick/models/superpoint.py:57: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   keypoints /= torch.tensor([(w * s - s / 2 - 0.5), (h * s - s / 2 - 0.5)],
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:211: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
#   associativity = torch.eye(len(all_points[-1]), dtype=torch.bool, device=device)
# /home/jaeho/GlueStick/gluestick/models/wireframe.py:248: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   'num_junctions': torch.tensor(num_true_junctions),
# /home/jaeho/GlueStick/gluestick/models/gluestick.py:98: TracerWarning: Using len to get tensor shape might cause the trace to be incorrect. Recommended usage would be tensor.shape[0]. Passing a tensor of different shape might lead to errors or silently give incorrect results.
#   b_size = len(data['keypoints0'])
# /home/jaeho/GlueStick/gluestick/models/gluestick.py:110: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if n_kpts0 == 0 or n_kpts1 == 0:
# /home/jaeho/GlueStick/gluestick/models/gluestick.py:306: TracerWarning: Converting a tensor to a Python float might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   size = kpts.new_tensor([[w, h]])
# /home/jaeho/GlueStick/gluestick/models/gluestick.py:159: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert torch.all(kpts0 >= -1) and torch.all(kpts0 <= 1)
# /home/jaeho/GlueStick/gluestick/models/gluestick.py:160: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert torch.all(kpts1 >= -1) and torch.all(kpts1 <= 1)
# /home/jaeho/GlueStick/gluestick/models/gluestick.py:164: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if n_lines0 != 0 and n_lines1 != 0:
# /home/jaeho/GlueStick/gluestick/models/gluestick.py:337: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert tuple(endpoints.shape[-2:]) == (2, 2)
# /home/jaeho/GlueStick/gluestick/models/gluestick.py:521: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if (layer.type == 'self' and lines_junc_idx0.shape[1] > 0
# /home/jaeho/GlueStick/gluestick/models/gluestick.py:197: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if n_lines0 > 0 and n_lines1 > 0:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[18], line 9
#       6 x = {'image0': torch_gray0, 'image1': torch_gray1}
#       7 # pred = model(x)Q
#       8 # torch.save(model.state_dict(), 'model.pt')
# ----> 9 script_model = torch.jit.trace(model,x)
#      10 script_model.save("GlueStick.pt")
#
# File ~/GlueStick/venv/lib/python3.8/site-packages/torch/jit/_trace.py:794, in trace(func, example_inputs, optimize, check_trace, check_inputs, check_tolerance, strict, _force_outplace, _module_class, _compilation_unit, example_kwarg_inputs, _store_inputs)
#     792         else:
#     793             raise RuntimeError("example_kwarg_inputs should be a dict")
# --> 794     return trace_module(
#     795         func,
#     796         {"forward": example_inputs},
#     797         None,
#     798         check_trace,
#     799         wrap_check_inputs(check_inputs),
#     800         check_tolerance,
#     801         strict,
#     802         _force_outplace,
#     803         _module_class,
#     804         example_inputs_is_kwarg=isinstance(example_kwarg_inputs, dict),
#     805         _store_inputs=_store_inputs
#     806     )
#     807 if (
#     808     hasattr(func, "__self__")
#     809     and isinstance(func.__self__, torch.nn.Module)
#     810     and func.__name__ == "forward"
#     811 ):
#     812     if example_inputs is None:
#
# File ~/GlueStick/venv/lib/python3.8/site-packages/torch/jit/_trace.py:1056, in trace_module(mod, inputs, optimize, check_trace, check_inputs, check_tolerance, strict, _force_outplace, _module_class, _compilation_unit, example_inputs_is_kwarg, _store_inputs)
#    1054 else:
#    1055     example_inputs = make_tuple(example_inputs)
# -> 1056     module._c._create_method_from_trace(
#    1057         method_name,
#    1058         func,
#    1059         example_inputs,
#    1060         var_lookup_fn,
#    1061         strict,
#    1062         _force_outplace,
#    1063         argument_names,
#    1064         _store_inputs
#    1065     )
#    1067 check_trace_method = module._c._get_method(method_name)
#    1069 # Check the trace against new traces created from user-specified inputs
#
# RuntimeError: Encountering a dict at the output of the tracer might cause the trace to be incorrect, this is only valid if the container structure does not change based on the module's inputs. Consider using a constant container instead (e.g. for `list`, use a `tuple` instead. for `dict`, use a `NamedTuple` instead). If you absolutely need this and know the side effects, pass strict=False to trace() to allow this behavior.
